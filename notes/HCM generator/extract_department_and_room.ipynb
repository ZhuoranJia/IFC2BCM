# %% [markdown]
# # Get the departments and rooms within each departments

# %%
# %matplotlib inline
import numpy as np
import compas
from compas.datastructures import Mesh
import compas.datastructures as ds
from compas_plotters import Plotter
import matplotlib.pyplot as plt
import networkx as nx 
import json
from pathlib import Path
from mpl_toolkits.mplot3d import Axes3D

# %%
fin_real = open("C:/Users/SID-DRW/OneDrive - Delft University of Technology/Desktop/new_boundaries_0204/GENERATING_GML/output.json")
j_real = json.loads(fin_real.read())

# %% [markdown]
# ## Get room names and areas

# %%
#make dict

def get_names_and_areas_dict(jsonfile):
    cellspaces = []
    room_names = []
    room_areas = []

    for i in jsonfile['PrimalSpaceFeatures']['CellSpace']:
        cellspaces.append(i)
    for cs in cellspaces:
        name = jsonfile['PrimalSpaceFeatures']['CellSpace'][cs]['name']
        room_names.append(name)

    for cs in cellspaces:
        area = jsonfile['PrimalSpaceFeatures']['CellSpace'][cs]['attributes']['area']
        room_areas.append({'area':area})
    
    name_and_area = dict(map(lambda i,j : (i,j) , room_names,room_areas))
    return name_and_area

dict_room_Name_and_area = get_names_and_areas_dict(j_real)
print(dict_room_Name_and_area)
print(len(dict_room_Name_and_area))
# Out:
# {'CENTRALWAITING1AC1': {'area': '127.0993141'}, 'WAITING/ACTIVITYAREA1DC1': {'area': '178.2169708'}, 'ROOF2R02': {'area': '578.7414997'}, 'CORRIDOR1EC1': {'area': '50.950835'}, 'ROOF3R01': {'area': '1729.774807'}, 'MAINMECHANICALROOM2D05': {'area': '226.04322'}, 'CORRIDOR2AC3': {'area': '25.4807999'}, 'CORRIDOR1BC2': {'area': '27.31731525'}, 'TECH.OFFICE2D18': {'area': '82.089156'}, 'CORRIDOR1CC1': {'area': '40.23448'}, 'PHARM.DISP.1A16': {'area': '65.22472'}, 'CORRIDOR1DC3': {'area': '29.65476604'}, 'PHYSICALEXAM1C18': {'area': '55.37747'}, 'LAB1B04': {'area': '51.1950656'}, 'CORRIDOR1BC4': {'area': '41.72148526'}, 'CORRIDOR2BC3': {'area': '24.92304611'}, 'CORRIDOR2BC5': {'area': '20.941674'}, 'RECEIVING/STORAGE1E24': {'area': '115.1199912'}, 'CORRIDOR2AC1': {'area': '39.02683601'}, 'CORRIDOR1CC3': {'area': '10.608154'}, 'PROVIDERCUBICLES1D16': {'area': '65.26142'}, 'CORRIDOR1DC7': {'area': '29.82494475'}, 'CORRIDOR2BC2': {'area': '27.59131613'}, 'BMETWORKSTATION1E16': {'area': '46.7310228'}, 'DENTALWAITING2A11': {'area': '31.7576639'}, 'CORRIDOR2CC3': {'area': '16.08426'}, 'CORRIDOR1AC5': {'area': '19.219196'}, 'CORRIDOR2DC2': {'area': '28.37771404'}, 'CORRIDOR1AC3': {'area': '15.00834681'}, 'PROVIDERCUBICLES1D25': {'area': '65.19988'}, 'CORRIDOR1DC6': {'area': '13.885884'}, 'CORRIDOR2CC2': {'area': '12.3633'}, 'PROSTH.LAB2C17': {'area': '28.58567199'}, 'CORRIDOR2AC4': {'area': '13.3551'}, 'M.STAFFTOILET2C07': {'area': '12.64593968'}, 'CORRIDOR1DC4': {'area': '14.1001505'}, 'CORRIDOR2CC1': {'area': '17.41818966'}, 'TECH.WORKSTATION1E06': {'area': '35.87712'}, 'CORRIDOR2CC4': {'area': '10.0491'}, 'OPENTOBELOW2AC1-B': {'area': '74.36477597'}, 'W.STAFFTOILET2C08': {'area': '11.81463896'}, 'RMOANALYST1A02': {'area': '26.65783112'}, 'OPT.EXAM/OFF.1C07': {'area': '16.30298113'}, 'RECEPTION1B01': {'area': '8.8082864'}, 'RECEPTION1B13': {'area': '21.46037404'}, 'CONSULT.2C03': {'area': '31.93688966'}, 'SYS.ANALYST2D04': {'area': '19.44117106'}, 'CORRIDOR2BC4': {'area': '11.546946'}, 'TEAMINTERACTION1D22': {'area': '22.55096041'}, 'CORRIDOR1AC2': {'area': '19.09846713'}, 'STAIR1CS3': {'area': '12.75474344'}, 'CORRIDOR2AC2': {'area': '13.92585484'}, 'LIBRARY/CONF.ROOM2A01': {'area': '24.92560559'}, 'CORRIDOR2CC5': {'area': '7.417722'}, 'CORRIDOR2DC1': {'area': '20.1438'}, 'ADMIN2A14': {'area': '31.49841497'}, "IMMUNIZ'NROOM1D40": {'area': '15.39988'}, 'LOUNGE1A10': {'area': '9.519166011'}, 'DIPCCLEAN2C12': {'area': '13.256738'}, 'FUNDUSCAMERAROOM1C09': {'area': '13.77182871'}, 'CENTRALMECH.RM.1E15': {'area': '27.1572756'}, 'ELEC.ROOM1E19': {'area': '8.888087942'}, 'BEEEQUIP.STORAGE1E23': {'area': '8.054825871'}, 'CORRIDOR1EC4': {'area': '8.463390043'}, 'CMDROFFICE2D11': {'area': '14.48541168'}, 'SOIL.UTL./TRASH2B25': {'area': '6.7255'}, 'STAFFLOUNGE1B10': {'area': '9.406536'}, 'DEVELOPING2A13': {'area': '6.885029095'}, 'X-RAY2A12': {'area': '10.34281402'}, 'CORRIDOR1AC4': {'area': '8.799656433'}, 'LOUNGE2C22': {'area': '10.32407253'}, 'INTERACTIONSTATION1D11': {'area': '11.874652'}, 'OHDTR#12A05': {'area': '10.44778121'}, 'TRICAREOFFICE1A07': {'area': '7.969378'}, 'CORRIDOR1DC2': {'area': '5.9337'}, 'CORRIDOR1DC8': {'area': '5.878835248'}, 'CORRIDOR1BC1': {'area': '5.0958'}, 'RADIOGRAPHICROOM1B19': {'area': '28.23269032'}, 'SEC.WAIT2D10': {'area': '15.66376'}, 'RMODIR.2D16': {'area': '8.967280013'}, 'OFFICE2B01': {'area': '8.597788478'}, 'WAITING2B11': {'area': '9.524945901'}, 'PHTECH2B18': {'area': '8.660007676'}, 'ROOF2R01': {'area': '50.907749'}, 'STAFFLOUNGE1E11': {'area': '13.65974'}, 'INTERACTIONSTATION1D07': {'area': '11.74148202'}, 'INTERACTIONSTATION1D32': {'area': '11.874652'}, 'TOILET1D18': {'area': '7.3873646'}, 'SPECIMENTOILET1B02': {'area': '4.903969'}, 'COUNSELING1A15': {'area': '5.868032'}, 'CORRIDOR1CC2': {'area': '7.569486'}, 'RECEPTION1C02': {'area': '8.818636'}, 'OPT.EXAM/OFF.1C10': {'area': '16.98138779'}, 'GROUPIS1D21': {'area': '17.922534'}, 'GROUPIS1D23': {'area': '17.917926'}, 'SUPER1E08': {'area': '9.10116'}, ...
# 264

# %% [markdown]
# ## Organize rooms to their deparments

# %%
def get_department_of_rooms_dict(room_name_area):

    output_data = {}

    # Loop through each item in the list to organize by department
    for key in room_name_area:
        # Extract department character (the last third character of the room name)
        department = 'Department$' + key[-3]
        
        # Check if the department key exists in the dictionary
        if department not in output_data:
            # If not, create a new list for this department
            output_data[department] = []
            
        # Append the room and area tuple to the appropriate department list
        output_data[department].append(key)

    return output_data

new_output_data = get_department_of_rooms_dict(dict_room_Name_and_area)
new_output_data
# Out:
# {'Department$A': ['CENTRALWAITING1AC1',
#   'CORRIDOR2AC3',
#   'PHARM.DISP.1A16',
#   'CORRIDOR2AC1',
#   'DENTALWAITING2A11',
#   'CORRIDOR1AC5',
#   'CORRIDOR1AC3',
#   'CORRIDOR2AC4',
#   'RMOANALYST1A02',
#   'CORRIDOR1AC2',
#   'CORRIDOR2AC2',
#   'LIBRARY/CONF.ROOM2A01',
#   'ADMIN2A14',
#   'LOUNGE1A10',
#   'DEVELOPING2A13',
#   'X-RAY2A12',
#   'CORRIDOR1AC4',
#   'OHDTR#12A05',
#   'TRICAREOFFICE1A07',
#   'COUNSELING1A15',
#   'M.TOILET1A12',
#   'W.TOILET1A09',
#   'SUPEROFFICE2A02',
#   'GEN.DENT.DTR#52A09',
#   'GEN.DENT.DTR#42A08',
#   'OHDTR#22A06',
#   'PATIENTADMIN.RECEPT.1A01',
#   'TRICAREOFFICE1A03',
#   'TRICAREOFFICE1A05',
#   'TRICAREOFFICE1A06',
#   'SEC.OFFICE2A03',
#   'OHDTR#32A07',
#   'STAFFTOILET1A13',
#   'STAIR1AS1',
#   'DENTALWAITING2A10',
#   'TRICAREOFFICE1A04',
#   'PHARM.OFFICE1A08',
#   'CORRIDOR2AC5',
#   'DENTALSURGEONOFFICE2A04',
#   'JAN.1A11',
#   'SUPER/NCOIC1A14',
#   'STAIR2AS1'],
#  'Department$D': ['WAITING/ACTIVITYAREA1DC1',
#   'MAINMECHANICALROOM2D05',
#   'TECH.OFFICE2D18',
#   'CORRIDOR1DC3',
#   'PROVIDERCUBICLES1D16',
#   'CORRIDOR1DC7',
#   'CORRIDOR2DC2',
#   'PROVIDERCUBICLES1D25',
#   'CORRIDOR1DC6',
#   'CORRIDOR1DC4',
#   'SYS.ANALYST2D04',
#   'TEAMINTERACTION1D22',
#   'CORRIDOR2DC1',
#   "IMMUNIZ'NROOM1D40",
#   'CMDROFFICE2D11',
#   'INTERACTIONSTATION1D11',
#   'CORRIDOR1DC2',
#   'CORRIDOR1DC8',
#   'SEC.WAIT2D10',
#   'RMODIR.2D16',
#   'INTERACTIONSTATION1D07',
#   'INTERACTIONSTATION1D32',
#   'TOILET1D18',
#   'GROUPIS1D21',
#   'GROUPIS1D23',
#   'CONF.ROOM2D20',
#   'LIBRARY/CLASSROOM2D21',
#   'INTERACTIONSTATION1D02',
#   'TRMTRM.DIRTYPROC.1D05',
#   'TRMTROOM1D38',
#   'PEDIATRICWTSandMSRS1D31',
#   'TOILET2D13',
#   'SL.LIN./TRASH1D01',
#   'SPECIMENCOLL.LAB1D12',
#   'MDISVIEW1D19',
#   'ADMINWORKSTATN.1D27',
#   'PEDIATRICWAITING1D33',
#   'JAN.CL.1D39',
#   'DIR.INFOMGR2D03',
#   'SCOPEWASH/DECON.1D06',
#   'INTERACTIONSTATION1D13',
#   'INTERACTIONSTATION1D36',
#   'WTSandMEAS.ROOM1D15',
#   'APPMTS1D20',
#   'WTSandMEAS.ROOM1D30',
#   'COPY/FILE2D06',
#   'ADMINOFFICE2D09',
#   'OPSSQUADCMDR2D14',
#   '1STSGT2D15',
#   'INTERACTIONSTATION1D10',
#   'CORRIDOR1DC5',
#   'QA/HRDDIRECTOR2D08',
#   'VEST.2D12',
#   'CREDENTIALSMGR2D17',
#   'READINESSNCOICOFFICE2D19',
#   'INTERACTIONSTATION1D08',
#   'INTERACTIONSTATION1D09',
#   'INTERACTIONSTATION1D28',
#   'INTERACTIONSTATION1D34',
#   'INTERACTIONSTATION1D35',
#   'JAN.CL.1D17',
#   'RECORDS1D24',
#   'SUPER2D07',
#   'SPECIMENTOILET1D14',
#   'TOILET1D26',
#   'PARTSSTORAGE2D01',
#   'DATA/ARCHIVESTORAGE2D02',
#   'TOILET1D04',
#   'CLEANU.1D03',
#   'CLEANU.1D37'],
#  'Department$R': ['ROOF2R02',
#   'ROOF3R01',
#   'ROOF2R01',
#   'ROOF3R02',
#   'ROOF3R04',
#   'ROOF3R03',
#   'ELEVATORE1'],
#  'Department$E': ['CORRIDOR1EC1',
#   'RECEIVING/STORAGE1E24',
#   'BMETWORKSTATION1E16',
#   'TECH.WORKSTATION1E06',
#   'CENTRALMECH.RM.1E15',
#   'ELEC.ROOM1E19',
#   'BEEEQUIP.STORAGE1E23',
#   'CORRIDOR1EC4',
#   'STAFFLOUNGE1E11',
#   'SUPER1E08',
#   'BIOMEDMAINT.ADMIN.1E18',
#   'WORKROOM1E26',
#   'ISOLATIONINTERACTIONSTATION1E33',
#   'TRASH1E20',
#   'ADPEQUIPSPACE1E25',
#   'HK.SUPV.OFFICE1E29',
#   'CORRIDOR1EC3',
#   'SOIL.LIN.1E30',
#   'HKEQUIP.STORAGE1E01',
#   'JAN.CL.1E03',
#   'CHIEFLOGOFFICE1E05',
#   'CONF.LIBRARY1E07',
#   'DISASTERSTOR.1E14',
#   'HAZ.STOR.1E17',
#   'FAC.MGR.OFFICE1E28',
#   'M.TOILET1E10',
#   'ISOLATIONTOILET1E12',
#   'BENCHSTOCKSTORAGE1E27',
#   'CORRIDOR1EC2',
#   'HKBREAKROOM1E04',
#   'W.TOILET1E09',
#   'ELEV.EQUIP.1E02',
#   'FLAMABLESTORAGE1E21',
#   'SEC.STORAGE1E22'],
#  'Department$B': ['CORRIDOR1BC2',
#   'LAB1B04',
#   'CORRIDOR1BC4',
#   'CORRIDOR2BC3',
#   'CORRIDOR2BC5',
#   'CORRIDOR2BC2',
#   'RECEPTION1B01',
#   'RECEPTION1B13',
#   'CORRIDOR2BC4',
#   'SOIL.UTL./TRASH2B25',
#   'STAFFLOUNGE1B10',
#   'CORRIDOR1BC1',
#   'RADIOGRAPHICROOM1B19',
#   'OFFICE2B01',
#   'WAITING2B11',
#   'PHTECH2B18',
#   'SPECIMENTOILET1B02',
#   'CORRIDOR1BC3',
#   'BLOODDRAW1B03',
#   'TECH.WORKROOM1B17',
#   'CORRIDOR2BC1',
#   'CORRIDOR2BC6',
#   'RECEPTION2B10',
#   'ELECTRICAL2B13',
#   'RECS/FORMSSTORAGE2B14',
#   'DRESS1B09',
#   'STAIR1BS2',
#   'OFFICE2B19',
#   'STAFFTOILET1B11',
#   'M.TOILET2B22',
#   'DRESS1B07',
#   'SOIL.UTL.1B14',
#   'COMM.ROOM1B21',
#   'ELEC.ROOM1B23',
#   'COMM.ROOM2B12',
#   'PHSUPER2B21',
#   'CL.UTL./KITCHENET2B17',
#   'CLEANSUP.andEQUIP.1B12',
#   'FILMVIEW1B15',
#   'JAN.CL.1B16',
#   'WAIT/ERGOM2B15',
#   'PHTECH2B16',
#   'BEETECH2B23',
#   'BEETECH2B24',
#   'STAIR2BS2',
#   'PAT./STAFFTOILET1B05',
#   'LABOFFICE1B06',
#   'CENT.STO.1B08',
#   'JAN.CL.2B20'],
#  'Department$C': ['CORRIDOR1CC1',
#   'PHYSICALEXAM1C18',
#   'CORRIDOR1CC3',
#   'CORRIDOR2CC3',
#   'CORRIDOR2CC2',
#   'PROSTH.LAB2C17',
#   'M.STAFFTOILET2C07',
#   'CORRIDOR2CC1',
#   'CORRIDOR2CC4',
#   'W.STAFFTOILET2C08',
#   'OPT.EXAM/OFF.1C07',
#   'CONSULT.2C03',
#   'STAIR1CS3',
#   'CORRIDOR2CC5',
#   'DIPCCLEAN2C12',
#   'FUNDUSCAMERAROOM1C09',
#   'LOUNGE2C22',
#   'CORRIDOR1CC2',
#   'RECEPTION1C02',
#   'OPT.EXAM/OFF.1C10',
#   'COMM.ROOM2C15',
#   'CERAMICLAB2C16',
#   'GEN.DENT.DTR#102C14',
#   'VISUALFIELD1C05',
#   'SCREENEYETEST1C08',
#   'ECGTEST1C16',
#   'STAIR2CS3',
#   'GEN.DENT.DTR#72C04',
#   'GEN.DENT.DTR#62C02',
#   'M.TOILET2C23',
#   'WAITING1C01',
#   'FITTING/DISP.1C04',
#   'COMM.ROOM1C13',
#   'JAN.CL.2C05',
#   'TRASH2C13',
#   'DIPCDECON2C10',
#   'GEN.DENT.DTR#92C09',
#   'TOILET1C12',
#   'W.TOILET2C24',
#   'CHIEFAEROMED.1C17',
#   'AUDIO1C19',
#   'ELEC.CL.1C11',
#   'HK2C11',
#   'SOIL.UTL./TRASH1C06',
#   'HIST./INTV.1C14',
#   'ELECTRICAL2C18',
#   'CENTRALISSUE2C19',
#   'GEN.DENT.DTR#82C06',
#   'JAN.CL.1C03',
#   'PESADMIN.OFFICE1C15',
#   'DTRSUPPORT2C01'],
#  'Department$1': ['OPENTOBELOW2AC1-B'],
#  'Department$0': ['COMPUTERROOM2D04A'],
#  'Department$2': ['X-RAYALCOVE2A12-A',
#   'OFFICE/EXAM2B8',
#   'W.TOILET2B5',
#   'TECHOFFICE2B7',
#   'STAFFTOILET2B6',
#   'JAN.CL.2B2',
#   'TECHOFFICE2B9'],
#  'Department$F': ['MECH.YARD1F01'],
#  'Department$5': ['GASSTORAGE1E15-A']}

# %%
def find_correct_department(room_name):
    for char in room_name:
        if char.isdigit():
            index = room_name.index(char) + 1
            return 'Department$' + room_name[index].upper()
    return None


def get_depart_room_dict(keys_to_remove, initial_dict):

    for key in keys_to_remove:
        rooms = initial_dict.pop(key, [])  # Remove the entry and get the rooms list
        for room in rooms:
            correct_department = find_correct_department(room)
            if correct_department in initial_dict:
                initial_dict[correct_department].append(room)
            else:
                initial_dict[correct_department] = [room]

    return initial_dict

keys_to_remove = ['Department$1', 'Department$0', 'Department$2', 'Department$5']
corrected_new_department = get_depart_room_dict(keys_to_remove,new_output_data)
corrected_new_department
# Out:
# {'Department$A': ['CENTRALWAITING1AC1',
#   'CORRIDOR2AC3',
#   'PHARM.DISP.1A16',
#   'CORRIDOR2AC1',
#   'DENTALWAITING2A11',
#   'CORRIDOR1AC5',
#   'CORRIDOR1AC3',
#   'CORRIDOR2AC4',
#   'RMOANALYST1A02',
#   'CORRIDOR1AC2',
#   'CORRIDOR2AC2',
#   'LIBRARY/CONF.ROOM2A01',
#   'ADMIN2A14',
#   'LOUNGE1A10',
#   'DEVELOPING2A13',
#   'X-RAY2A12',
#   'CORRIDOR1AC4',
#   'OHDTR#12A05',
#   'TRICAREOFFICE1A07',
#   'COUNSELING1A15',
#   'M.TOILET1A12',
#   'W.TOILET1A09',
#   'SUPEROFFICE2A02',
#   'GEN.DENT.DTR#52A09',
#   'GEN.DENT.DTR#42A08',
#   'OHDTR#22A06',
#   'PATIENTADMIN.RECEPT.1A01',
#   'TRICAREOFFICE1A03',
#   'TRICAREOFFICE1A05',
#   'TRICAREOFFICE1A06',
#   'SEC.OFFICE2A03',
#   'OHDTR#32A07',
#   'STAFFTOILET1A13',
#   'STAIR1AS1',
#   'DENTALWAITING2A10',
#   'TRICAREOFFICE1A04',
#   'PHARM.OFFICE1A08',
#   'CORRIDOR2AC5',
#   'DENTALSURGEONOFFICE2A04',
#   'JAN.1A11',
#   'SUPER/NCOIC1A14',
#   'STAIR2AS1',
#   'OPENTOBELOW2AC1-B',
#   'X-RAYALCOVE2A12-A'],
#  'Department$D': ['WAITING/ACTIVITYAREA1DC1',
#   'MAINMECHANICALROOM2D05',
#   'TECH.OFFICE2D18',
#   'CORRIDOR1DC3',
#   'PROVIDERCUBICLES1D16',
#   'CORRIDOR1DC7',
#   'CORRIDOR2DC2',
#   'PROVIDERCUBICLES1D25',
#   'CORRIDOR1DC6',
#   'CORRIDOR1DC4',
#   'SYS.ANALYST2D04',
#   'TEAMINTERACTION1D22',
#   'CORRIDOR2DC1',
#   "IMMUNIZ'NROOM1D40",
#   'CMDROFFICE2D11',
#   'INTERACTIONSTATION1D11',
#   'CORRIDOR1DC2',
#   'CORRIDOR1DC8',
#   'SEC.WAIT2D10',
#   'RMODIR.2D16',
#   'INTERACTIONSTATION1D07',
#   'INTERACTIONSTATION1D32',
#   'TOILET1D18',
#   'GROUPIS1D21',
#   'GROUPIS1D23',
#   'CONF.ROOM2D20',
#   'LIBRARY/CLASSROOM2D21',
#   'INTERACTIONSTATION1D02',
#   'TRMTRM.DIRTYPROC.1D05',
#   'TRMTROOM1D38',
#   'PEDIATRICWTSandMSRS1D31',
#   'TOILET2D13',
#   'SL.LIN./TRASH1D01',
#   'SPECIMENCOLL.LAB1D12',
#   'MDISVIEW1D19',
#   'ADMINWORKSTATN.1D27',
#   'PEDIATRICWAITING1D33',
#   'JAN.CL.1D39',
#   'DIR.INFOMGR2D03',
#   'SCOPEWASH/DECON.1D06',
#   'INTERACTIONSTATION1D13',
#   'INTERACTIONSTATION1D36',
#   'WTSandMEAS.ROOM1D15',
#   'APPMTS1D20',
#   'WTSandMEAS.ROOM1D30',
#   'COPY/FILE2D06',
#   'ADMINOFFICE2D09',
#   'OPSSQUADCMDR2D14',
#   '1STSGT2D15',
#   'INTERACTIONSTATION1D10',
#   'CORRIDOR1DC5',
#   'QA/HRDDIRECTOR2D08',
#   'VEST.2D12',
#   'CREDENTIALSMGR2D17',
#   'READINESSNCOICOFFICE2D19',
#   'INTERACTIONSTATION1D08',
#   'INTERACTIONSTATION1D09',
#   'INTERACTIONSTATION1D28',
#   'INTERACTIONSTATION1D34',
#   'INTERACTIONSTATION1D35',
#   'JAN.CL.1D17',
#   'RECORDS1D24',
#   'SUPER2D07',
#   'SPECIMENTOILET1D14',
#   'TOILET1D26',
#   'PARTSSTORAGE2D01',
#   'DATA/ARCHIVESTORAGE2D02',
#   'TOILET1D04',
#   'CLEANU.1D03',
#   'CLEANU.1D37',
#   'COMPUTERROOM2D04A'],
#  'Department$R': ['ROOF2R02',
#   'ROOF3R01',
#   'ROOF2R01',
#   'ROOF3R02',
#   'ROOF3R04',
#   'ROOF3R03',
#   'ELEVATORE1'],
#  'Department$E': ['CORRIDOR1EC1',
#   'RECEIVING/STORAGE1E24',
#   'BMETWORKSTATION1E16',
#   'TECH.WORKSTATION1E06',
#   'CENTRALMECH.RM.1E15',
#   'ELEC.ROOM1E19',
#   'BEEEQUIP.STORAGE1E23',
#   'CORRIDOR1EC4',
#   'STAFFLOUNGE1E11',
#   'SUPER1E08',
#   'BIOMEDMAINT.ADMIN.1E18',
#   'WORKROOM1E26',
#   'ISOLATIONINTERACTIONSTATION1E33',
#   'TRASH1E20',
#   'ADPEQUIPSPACE1E25',
#   'HK.SUPV.OFFICE1E29',
#   'CORRIDOR1EC3',
#   'SOIL.LIN.1E30',
#   'HKEQUIP.STORAGE1E01',
#   'JAN.CL.1E03',
#   'CHIEFLOGOFFICE1E05',
#   'CONF.LIBRARY1E07',
#   'DISASTERSTOR.1E14',
#   'HAZ.STOR.1E17',
#   'FAC.MGR.OFFICE1E28',
#   'M.TOILET1E10',
#   'ISOLATIONTOILET1E12',
#   'BENCHSTOCKSTORAGE1E27',
#   'CORRIDOR1EC2',
#   'HKBREAKROOM1E04',
#   'W.TOILET1E09',
#   'ELEV.EQUIP.1E02',
#   'FLAMABLESTORAGE1E21',
#   'SEC.STORAGE1E22',
#   'GASSTORAGE1E15-A'],
#  'Department$B': ['CORRIDOR1BC2',
#   'LAB1B04',
#   'CORRIDOR1BC4',
#   'CORRIDOR2BC3',
#   'CORRIDOR2BC5',
#   'CORRIDOR2BC2',
#   'RECEPTION1B01',
#   'RECEPTION1B13',
#   'CORRIDOR2BC4',
#   'SOIL.UTL./TRASH2B25',
#   'STAFFLOUNGE1B10',
#   'CORRIDOR1BC1',
#   'RADIOGRAPHICROOM1B19',
#   'OFFICE2B01',
#   'WAITING2B11',
#   'PHTECH2B18',
#   'SPECIMENTOILET1B02',
#   'CORRIDOR1BC3',
#   'BLOODDRAW1B03',
#   'TECH.WORKROOM1B17',
#   'CORRIDOR2BC1',
#   'CORRIDOR2BC6',
#   'RECEPTION2B10',
#   'ELECTRICAL2B13',
#   'RECS/FORMSSTORAGE2B14',
#   'DRESS1B09',
#   'STAIR1BS2',
#   'OFFICE2B19',
#   'STAFFTOILET1B11',
#   'M.TOILET2B22',
#   'DRESS1B07',
#   'SOIL.UTL.1B14',
#   'COMM.ROOM1B21',
#   'ELEC.ROOM1B23',
#   'COMM.ROOM2B12',
#   'PHSUPER2B21',
#   'CL.UTL./KITCHENET2B17',
#   'CLEANSUP.andEQUIP.1B12',
#   'FILMVIEW1B15',
#   'JAN.CL.1B16',
#   'WAIT/ERGOM2B15',
#   'PHTECH2B16',
#   'BEETECH2B23',
#   'BEETECH2B24',
#   'STAIR2BS2',
#   'PAT./STAFFTOILET1B05',
#   'LABOFFICE1B06',
#   'CENT.STO.1B08',
#   'JAN.CL.2B20',
#   'OFFICE/EXAM2B8',
#   'W.TOILET2B5',
#   'TECHOFFICE2B7',
#   'STAFFTOILET2B6',
#   'JAN.CL.2B2',
#   'TECHOFFICE2B9'],
#  'Department$C': ['CORRIDOR1CC1',
#   'PHYSICALEXAM1C18',
#   'CORRIDOR1CC3',
#   'CORRIDOR2CC3',
#   'CORRIDOR2CC2',
#   'PROSTH.LAB2C17',
#   'M.STAFFTOILET2C07',
#   'CORRIDOR2CC1',
#   'CORRIDOR2CC4',
#   'W.STAFFTOILET2C08',
#   'OPT.EXAM/OFF.1C07',
#   'CONSULT.2C03',
#   'STAIR1CS3',
#   'CORRIDOR2CC5',
#   'DIPCCLEAN2C12',
#   'FUNDUSCAMERAROOM1C09',
#   'LOUNGE2C22',
#   'CORRIDOR1CC2',
#   'RECEPTION1C02',
#   'OPT.EXAM/OFF.1C10',
#   'COMM.ROOM2C15',
#   'CERAMICLAB2C16',
#   'GEN.DENT.DTR#102C14',
#   'VISUALFIELD1C05',
#   'SCREENEYETEST1C08',
#   'ECGTEST1C16',
#   'STAIR2CS3',
#   'GEN.DENT.DTR#72C04',
#   'GEN.DENT.DTR#62C02',
#   'M.TOILET2C23',
#   'WAITING1C01',
#   'FITTING/DISP.1C04',
#   'COMM.ROOM1C13',
#   'JAN.CL.2C05',
#   'TRASH2C13',
#   'DIPCDECON2C10',
#   'GEN.DENT.DTR#92C09',
#   'TOILET1C12',
#   'W.TOILET2C24',
#   'CHIEFAEROMED.1C17',
#   'AUDIO1C19',
#   'ELEC.CL.1C11',
#   'HK2C11',
#   'SOIL.UTL./TRASH1C06',
#   'HIST./INTV.1C14',
#   'ELECTRICAL2C18',
#   'CENTRALISSUE2C19',
#   'GEN.DENT.DTR#82C06',
#   'JAN.CL.1C03',
#   'PESADMIN.OFFICE1C15',
#   'DTRSUPPORT2C01'],
#  'Department$F': ['MECH.YARD1F01']}
