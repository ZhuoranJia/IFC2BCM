# %%
with open("C:/Users/SID-DRW/OneDrive - Delft University of Technology/Desktop/new_boundaries_0204/hugo_test/newCellspace.csv", "r") as f:
    for line in f.readlines():
        line = line.strip('\n')
        line1=line.replace(" ", ",")
        line1=line1.replace(" ", ",")

        h1=str(' '+"<ns5:cellSpaceMember>"+'\n')
        h2=str(' <ns5:CellSpace gml:id="'+line1.split(",")[0]+'">'+'\n')
        h3=str('<gml:description>'+'\n')
        h4=str(' story=""'+line1.split(",")[1]+'">'+'\n')
        h5=str('</gml:description>'+'\n')
        h6=str('<gml:name>'+'\n')
        h7=str(str(line1.split(",")[0]) +'\n')
        h8=str('</gml:name>'+'\n')
        h9=str('<gml:boundedBy xsi:nil="true"/>'+'\n')
        h10=str('<ns5:cellSpaceGeometry>'+'\n')
        h11=str(' <ns5:Geometry3D>'+'\n')
        h12=str('<gml:Solid gml:id="CG'+line1.split(",")[0]+'">'+'\n')
        h13=str(' <gml:exterior>'+'\n')
        h14=str(' <gml:Shell>'+'\n')
        h15=str(' <gml:surfaceMember>'+'\n')
        h16=str(' <gml:Polygon>'+'\n')
        h17=str(' <gml:exterior>'+'\n')
        h18=str(' <gml:LinearRing>'+'\n')
        h19=str(' <gml:pos srsDimension="3">'+'\n')
        h20=str(str(line1.split(",")[2])+" "+line1.split(",")[3]+" "+line1.split(",")[4]+'\n')
        h21=str('</gml:pos>'+'\n')
        h22=str('<gml:pos srsDimension="3">'+'\n')
        h23=str(str(line1.split(",")[5])+" "+line1.split(",")[6]+" "+line1.split(",")[7]+'\n')
        h24=str('</gml:pos>'+'\n')
        h25=str('<gml:pos srsDimension="3">'+'\n')
        h26=str(str(line1.split(",")[8])+" "+line1.split(",")[9]+" "+line1.split(",")[10]+'\n')
        h27=str('</gml:pos>'+'\n')
        h28=str('<gml:pos srsDimension="3">'+'\n')
        h29=str(str(line1.split(",")[11])+" "+line1.split(",")[12]+" "+line1.split(",")[13]+'\n')
        h30=str('</gml:pos>'+'\n')
        h31=str('<gml:pos srsDimension="3">'+'\n')
        h32=str(str(line1.split(",")[2])+" "+line1.split(",")[3]+" "+line1.split(",")[4]+'\n')

        #add or not
        h33=str('</gml:pos>'+'\n'+'</gml:LinearRing>'+'\n'+'</gml:exterior>'+'\n'+'</gml:Polygon>'+'\n'+'</gml:surfaceMember>'+'\n'+'<gml:surfaceMember>'+'\n'+'<gml:Polygon>'+'\n'+'<gml:exterior>'+'\n'+'<gml:LinearRing>'+'\n'+'<gml:pos srsDimension="3">'+'\n')

        h34=str(str(line1.split(",")[2])+" "+line1.split(",")[3]+" "+line1.split(",")[4]+'\n') 
        h35=str('</gml:pos>'+'\n') 
        h36=str('<gml:pos srsDimension="3">'+'\n') 
        h37=str(str(line1.split(",")[5])+" "+line1.split(",")[6]+" "+line1.split(",")[7]+'\n') 
        h38=str('</gml:pos>'+'\n') 
        h39=str('<gml:pos srsDimension="3">'+'\n') 
        h40=str(str(line1.split(",")[17])+" "+line1.split(",")[18]+" "+line1.split(",")[19]+'\n') 
        h41=str('</gml:pos>'+'\n') 
        h42=str('<gml:pos srsDimension="3">'+'\n') 
        h43=str(str(line1.split(",")[14])+" "+line1.split(",")[15]+" "+line1.split(",")[16]+'\n') 
        h44=str('</gml:pos>'+'\n') 
        h45=str('<gml:pos srsDimension="3">'+'\n') 
        h46=str(str(line1.split(",")[2])+" "+line1.split(",")[3]+" "+line1.split(",")[4]+'\n') 
        h47=str('</gml:pos>'+'\n'+'</gml:LinearRing>'+'\n'+'</gml:exterior>'+'\n'+'</gml:Polygon>'+'\n'+'</gml:surfaceMember>'+'\n'+'<gml:surfaceMember>'+'\n'+'<gml:Polygon>'+'\n'+'<gml:exterior>'+'\n'+'<gml:LinearRing>'+'\n'+'<gml:pos srsDimension="3">'+'\n')
        h48=str(str(line1.split(",")[5])+" "+line1.split(",")[6]+" "+line1.split(",")[7]+'\n') 
        h49=str('</gml:pos>'+'\n') 
        h50=str('<gml:pos srsDimension="3">'+'\n') 
        h51=str(str(line1.split(",")[8])+" "+line1.split(",")[9]+" "+line1.split(",")[10]+'\n') 
        h52=str('</gml:pos>'+'\n') 
        h53=str('<gml:pos srsDimension="3">'+'\n') 
        h54=str(str(line1.split(",")[20])+" "+line1.split(",")[21]+" "+line1.split(",")[22]+'\n') 
        h55=str('</gml:pos>'+'\n') 
        h56=str('<gml:pos srsDimension="3">'+'\n') 
        h57=str(str(line1.split(",")[17])+" "+line1.split(",")[18]+" "+line1.split(",")[19]+'\n') 
        h58=str('</gml:pos>'+'\n') 
        h59=str('<gml:pos srsDimension="3">'+'\n') 
        h60=str(str(line1.split(",")[5])+" "+line1.split(",")[6]+" "+line1.split(",")[6]+'\n')
        h61=str('</gml:pos>'+'\n'+'</gml:LinearRing>'+'\n'+'</gml:exterior>'+'\n'+'</gml:Polygon>'+'\n'+'</gml:surfaceMember>'+'\n'+'<gml:surfaceMember>'+'\n'+'<gml:Polygon>'+'\n'+'<gml:exterior>'+'\n'+'<gml:LinearRing>'+'\n'+'<gml:pos srsDimension="3">'+'\n')
        h62=str(str(line1.split(",")[8])+" "+line1.split(",")[9]+" "+line1.split(",")[10]+'\n') 
        h63=str('</gml:pos>'+'\n') 
        h64=str('<gml:pos srsDimension="3">'+'\n') 
        h65=str(str(line1.split(",")[10])+" "+line1.split(",")[11]+" "+line1.split(",")[12]+'\n') 
        h66=str('</gml:pos>'+'\n') 
        h67=str('<gml:pos srsDimension="3">'+'\n') 
        h68=str(str(line1.split(",")[23])+" "+line1.split(",")[24]+" "+line1.split(",")[25]+'\n') 
        h69=str('</gml:pos>'+'\n') 
        h70=str('<gml:pos srsDimension="3">'+'\n') 
        h71=str(str(line1.split(",")[20])+" "+line1.split(",")[21]+" "+line1.split(",")[22]+'\n') 
        h72=str('</gml:pos>'+'\n') 
        h73=str('<gml:pos srsDimension="3">'+'\n') 
        h74=str(str(line1.split(",")[8])+" "+line1.split(",")[9]+" "+line1.split(",")[10]+'\n')
        h75=str('</gml:pos>'+'\n'+'</gml:LinearRing>'+'\n'+'</gml:exterior>'+'\n'+'</gml:Polygon>'+'\n'+'</gml:surfaceMember>'+'\n'+'<gml:surfaceMember>'+'\n'+'<gml:Polygon>'+'\n'+'<gml:exterior>'+'\n'+'<gml:LinearRing>'+'\n'+'<gml:pos srsDimension="3">'+'\n') 
        h76=str(str(line1.split(",")[11])+" "+line1.split(",")[12]+" "+line1.split(",")[13]+'\n') 
        h77=str('</gml:pos>'+'\n') 
        h78=str('<gml:pos srsDimension="3">'+'\n') 
        h79=str(str(line1.split(",")[2])+" "+line1.split(",")[3]+" "+line1.split(",")[4]+'\n') 
        h80=str('</gml:pos>'+'\n') 
        h81=str('<gml:pos srsDimension="3">'+'\n')
        h82=str(str(line1.split(",")[14])+" "+line1.split(",")[15]+" "+line1.split(",")[16]+'\n') 
        h83=str('</gml:pos>'+'\n') 
        h84=str('<gml:pos srsDimension="3">'+'\n') 
        h85=str(str(line1.split(",")[23])+" "+line1.split(",")[24]+" "+line1.split(",")[25]+'\n') 
        h86=str('</gml:pos>'+'\n') 
        h87=str('<gml:pos srsDimension="3">'+'\n') 
        h88=str(str(line1.split(",")[11])+" "+line1.split(",")[12]+" "+line1.split(",")[13]+'\n') 
        h89=str('</gml:pos>'+'\n'+'</gml:LinearRing>'+'\n'+'</gml:exterior>'+'\n'+'</gml:Polygon>'+'\n'+'</gml:surfaceMember>'+'\n'+'<gml:surfaceMember>'+'\n'+'<gml:Polygon>'+'\n'+'<gml:exterior>'+'\n'+'<gml:LinearRing>'+'\n'+'<gml:pos srsDimension="3">'+'\n')
        h90=str(str(line1.split(",")[14])+" "+line1.split(",")[15]+" "+line1.split(",")[16]+'\n') 
        h91=str('</gml:pos>'+'\n') 
        h92=str('<gml:pos srsDimension="3">'+'\n') 
        h93=str(str(line1.split(",")[17])+" "+line1.split(",")[18]+" "+line1.split(",")[19]+'\n') 
        h94=str('</gml:pos>'+'\n') 
        h95=str('<gml:pos srsDimension="3">'+'\n') 
        h96=str(str(line1.split(",")[20])+" "+line1.split(",")[21]+" "+line1.split(",")[22]+'\n') 
        h97=str('</gml:pos>'+'\n') 
        h98=str('<gml:pos srsDimension="3">'+'\n') 
        h99=str(str(line1.split(",")[23])+" "+line1.split(",")[24]+" "+line1.split(",")[25]+'\n') 
        h100=str('</gml:pos>'+'\n') 
        h101=str('<gml:pos srsDimension="3">'+'\n') 
        h102=str(str(line1.split(",")[14])+" "+line1.split(",")[15]+" "+line1.split(",")[16]+'\n') 
        h103=str('</gml:pos>'+'\n'+'</gml:LinearRing>'+'\n'+'</gml:exterior>'+'\n'+'</gml:Polygon>'+'\n'+'</gml:surfaceMember>'+'\n'+'</gml:Shell>'+'\n'+'</gml:exterior>'+'\n'+'</gml:Solid>'+'\n'+'</ns5:Geometry3D>'+'\n'+'</ns5:cellSpaceGeometry>'+'\n'+'</ns5:CellSpace>'+'</ns5:cellSpaceMember>') 

        h=... 

        with open("C:/Users/SID-DRW/OneDrive - Delft University of Technology/Desktop/new_boundaries_0204/hugo_test/cellspace.txt","a") as f: 
            f.write(h)  
            print(h)
# Out:
#  <ns5:cellSpaceMember>
#  <ns5:CellSpace gml:id="C1">
# <gml:description>
#  story=""Room1">
# </gml:description>
# <gml:name>
# C1
# </gml:name>
# <gml:boundedBy xsi:nil="true"/>
# <ns5:cellSpaceGeometry>
#  <ns5:Geometry3D>
# <gml:Solid gml:id="CGC1">
#  <gml:exterior>
#  <gml:Shell>
#  <gml:surfaceMember>
#  <gml:Polygon>
#  <gml:exterior>
#  <gml:LinearRing>
#  <gml:pos srsDimension="3">
# "0 0 0
# </gml:pos>
# <gml:pos srsDimension="3">
# " "100 0
# </gml:pos>
# <gml:pos srsDimension="3">
# 0" "100 100
# </gml:pos>
# <gml:pos srsDimension="3">
# 0" "0 100
# </gml:pos>
# <gml:pos srsDimension="3">
# "0 0 0
# </gml:pos>
# </gml:LinearRing>
# </gml:exterior>
# </gml:Polygon>
# </gml:surfaceMember>
# <gml:surfaceMember>
# <gml:Polygon>
# <gml:exterior>
# <gml:LinearRing>
# <gml:pos srsDimension="3">
# "0 0 0
# </gml:pos>
# <gml:pos srsDimension="3">
# " "100 0
# </gml:pos>
# <gml:pos srsDimension="3">
# 0 " "100
# </gml:pos>
# <gml:pos srsDimension="3">
# 0" "0 0
# </gml:pos>
# ...
